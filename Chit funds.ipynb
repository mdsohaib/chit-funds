# %% [markdown]
# # Problem Statement :
# A chit fund has 25 members. Each month they contribute Rs 2000 each.
# End of the month, the person who bids the lowest for the corpus, gets his bid.
# The group organizer gets paid a fixed commission of Rs 2500 each month (5% of 25*2000).It is deducted from the bid winner's corpus.  The remaining amount is distributed among all the 25 customers equally.
#
# Enclosed excel has the table with cashflows for each month.
#
# Task :
# 	•	What is the Annualized  Return of the person who bids in the last month ?
# 	•	What is the Annualized Return of the person who bids in the first month ?
# 	•	Write an R/Python script which calculates the annualized return of chit fund participant ?- Show the Return % for each month's bid winner.
#
#
# ## As per Wikipedia chit funds explanation
# https://en.wikipedia.org/wiki/Chit_fund
#
#  Each month, the subscribers put in their monthly installments into the pot. Then, an open auction is conducted to determine the lowest sum a subscriber is willing to take that month.
#  For example, if the monthly installment is ₹1000 and there are 50 members, the pot in the first month will contain ₹50,000.
#  If the auction determines a winner who is willing to accept ₹45,000 for that month, the surplus ₹5,000 is distributed to the other 49 members, after subtracting fees paid to the organizer. The subscriber who won the auction was able to access ₹45,000 in the first month and the others benefited in their share of the ₹5,000 surplus. The process repeats, distributing the auction amount to one member each month.

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df= pd.read_csv('chit fund exercise.csv')

# %%
df.head()
# Out:
#    Month  Contribution  Amount won by the bidder  \
# 0      1          2000                     40000
# 1      2          2000                     42000
# 2      3          2000                     45000
# 3      4          2000                     48000
# 4      5          2000                     40000
#
#    Chit fund organizer commission  Net amount recd by Bid winner  \
# 0                            2500                          37500
# 1                            2500                          39500
# 2                            2500                          42500
# 3                            2500                          45500
# 4                            2500                          37500
#
#    Amount returned to everyone in the group
# 0                                       400
# 1                                       320
# 2                                       200
# 3                                        80
# 4                                       400

# %%
df.describe()
# Out:
#            Month  Contribution  Amount won by the bidder  \
# count  25.000000          25.0                 25.000000
# mean   13.000000        2000.0              43800.000000
# std     7.359801           0.0               2857.738033
# min     1.000000        2000.0              40000.000000
# 25%     7.000000        2000.0              42000.000000
# 50%    13.000000        2000.0              43000.000000
# 75%    19.000000        2000.0              45000.000000
# max    25.000000        2000.0              50000.000000
#
#        Chit fund organizer commission  Net amount recd by Bid winner  \
# count                            25.0                      25.000000
# mean                           2500.0                   41300.000000
# std                               0.0                    2857.738033
# min                            2500.0                   37500.000000
# 25%                            2500.0                   39500.000000
# 50%                            2500.0                   40500.000000
# 75%                            2500.0                   42500.000000
# max                            2500.0                   47500.000000
#
#        Amount returned to everyone in the group
# count                                 25.000000
# mean                                 248.000000
# std                                  114.309521
# min                                    0.000000
# 25%                                  200.000000
# 50%                                  280.000000
# 75%                                  320.000000
# max                                  400.000000

# %%
df
# Out:
#     Month  Contribution  Amount won by the bidder  \
# 0       1          2000                     40000
# 1       2          2000                     42000
# 2       3          2000                     45000
# 3       4          2000                     48000
# 4       5          2000                     40000
# 5       6          2000                     42000
# 6       7          2000                     43000
# 7       8          2000                     44000
# 8       9          2000                     40000
# 9      10          2000                     42000
# 10     11          2000                     45000
# 11     12          2000                     48000
# 12     13          2000                     40000
# 13     14          2000                     42000
# 14     15          2000                     43000
# 15     16          2000                     43000
# 16     17          2000                     41000
# 17     18          2000                     42000
# 18     19          2000                     45000
# 19     20          2000                     45000
# 20     21          2000                     44000
# 21     22          2000                     46000
# 22     23          2000                     47000
# 23     24          2000                     48000
# 24     25          2000                     50000
#
#     Chit fund organizer commission  Net amount recd by Bid winner  \
# 0                             2500                          37500
# 1                             2500                          39500
# 2                             2500                          42500
# 3                             2500                          45500
# 4                             2500                          37500
# 5                             2500                          39500
# 6                             2500                          40500
# 7                             2500                          41500
# 8                             2500                          37500
# 9                             2500                          39500
# 10                            2500                          42500
# 11                            2500                          45500
# 12                            2500                          37500
# 13                            2500                          39500
# 14                            2500                          40500
# 15                            2500                          40500
# 16                            2500                          38500
# 17                            2500                          39500
# 18                            2500                          42500
# 19                            2500                          42500
# 20                            2500                          41500
# 21                            2500                          43500
# 22                            2500                          44500
# 23                            2500                          45500
# 24                            2500                          47500
#
#     Amount returned to everyone in the group
# 0                                        400
# 1                                        320
# 2                                        200
# 3                                         80
# 4                                        400
# 5                                        320
# 6                                        280
# 7                                        240
# 8                                        400
# 9                                        320
# 10                                       200
# 11                                        80
# 12                                       400
# 13                                       320
# 14                                       280
# 15                                       280
# 16                                       360
# 17                                       320
# 18                                       200
# 19                                       200
# 20                                       240
# 21                                       160
# 22                                       120
# 23                                        80
# 24                                         0

# %%
df['Amount returned to everyone in the group'].sum()
# Out:
# 6200

# %%
#amount taken by last bidder is 47500+6200 =53700
#amount taken by first bidder is 37500
# return % of each month bidder is

# %%
#creating a new column with summing

list=[]
col = df['Amount returned to everyone in the group']

sum = 0
list.append(0)
for num in col:
    sum += num
    list.append(sum)

# %%
list
# Out:
# [0,
#  400,
#  720,
#  920,
#  1000,
#  1400,
#  1720,
#  2000,
#  2240,
#  2640,
#  2960,
#  3160,
#  3240,
#  3640,
#  3960,
#  4240,
#  4520,
#  4880,
#  5200,
#  5400,
#  5600,
#  5840,
#  6000,
#  6120,
#  6200,
#  6200]

# %%
list1=list[:25]

# %%
list1
# Out:
# [0,
#  400,
#  720,
#  920,
#  1000,
#  1400,
#  1720,
#  2000,
#  2240,
#  2640,
#  2960,
#  3160,
#  3240,
#  3640,
#  3960,
#  4240,
#  4520,
#  4880,
#  5200,
#  5400,
#  5600,
#  5840,
#  6000,
#  6120,
#  6200]

# %%
df['Remaining amount returned to bid winner']=list1

# %%
df.head()
# Out:
#    Month  Contribution  Amount won by the bidder  \
# 0      1          2000                     40000
# 1      2          2000                     42000
# 2      3          2000                     45000
# 3      4          2000                     48000
# 4      5          2000                     40000
#
#    Chit fund organizer commission  Net amount recd by Bid winner  \
# 0                            2500                          37500
# 1                            2500                          39500
# 2                            2500                          42500
# 3                            2500                          45500
# 4                            2500                          37500
#
#    Amount returned to everyone in the group  \
# 0                                       400
# 1                                       320
# 2                                       200
# 3                                        80
# 4                                       400
#
#    Remaining amount returned to bid winner
# 0                                        0
# 1                                      400
# 2                                      720
# 3                                      920
# 4                                     1000

# %%
df['Total amount returned to Bid Winner']=df['Net amount recd by Bid winner']+df['Remaining amount returned to bid winner']

# %%
df.head()
# Out:
#    Month  Contribution  Amount won by the bidder  \
# 0      1          2000                     40000
# 1      2          2000                     42000
# 2      3          2000                     45000
# 3      4          2000                     48000
# 4      5          2000                     40000
#
#    Chit fund organizer commission  Net amount recd by Bid winner  \
# 0                            2500                          37500
# 1                            2500                          39500
# 2                            2500                          42500
# 3                            2500                          45500
# 4                            2500                          37500
#
#    Amount returned to everyone in the group  \
# 0                                       400
# 1                                       320
# 2                                       200
# 3                                        80
# 4                                       400
#
#    Remaining amount returned to bid winner  \
# 0                                        0
# 1                                      400
# 2                                      720
# 3                                      920
# 4                                     1000
#
#    Total amount returned to Bid Winner
# 0                                37500
# 1                                39900
# 2                                43220
# 3                                46420
# 4                                38500

# %%
df["Return % for each month's bid winner"]=(df['Total amount returned to Bid Winner']/50000)*100

# %%
df
# Out:
#     Month  Contribution  Amount won by the bidder  \
# 0       1          2000                     40000
# 1       2          2000                     42000
# 2       3          2000                     45000
# 3       4          2000                     48000
# 4       5          2000                     40000
# 5       6          2000                     42000
# 6       7          2000                     43000
# 7       8          2000                     44000
# 8       9          2000                     40000
# 9      10          2000                     42000
# 10     11          2000                     45000
# 11     12          2000                     48000
# 12     13          2000                     40000
# 13     14          2000                     42000
# 14     15          2000                     43000
# 15     16          2000                     43000
# 16     17          2000                     41000
# 17     18          2000                     42000
# 18     19          2000                     45000
# 19     20          2000                     45000
# 20     21          2000                     44000
# 21     22          2000                     46000
# 22     23          2000                     47000
# 23     24          2000                     48000
# 24     25          2000                     50000
#
#     Chit fund organizer commission  Net amount recd by Bid winner  \
# 0                             2500                          37500
# 1                             2500                          39500
# 2                             2500                          42500
# 3                             2500                          45500
# 4                             2500                          37500
# 5                             2500                          39500
# 6                             2500                          40500
# 7                             2500                          41500
# 8                             2500                          37500
# 9                             2500                          39500
# 10                            2500                          42500
# 11                            2500                          45500
# 12                            2500                          37500
# 13                            2500                          39500
# 14                            2500                          40500
# 15                            2500                          40500
# 16                            2500                          38500
# 17                            2500                          39500
# 18                            2500                          42500
# 19                            2500                          42500
# 20                            2500                          41500
# 21                            2500                          43500
# 22                            2500                          44500
# 23                            2500                          45500
# 24                            2500                          47500
#
#     Amount returned to everyone in the group  \
# 0                                        400
# 1                                        320
# 2                                        200
# 3                                         80
# 4                                        400
# 5                                        320
# 6                                        280
# 7                                        240
# 8                                        400
# 9                                        320
# 10                                       200
# 11                                        80
# 12                                       400
# 13                                       320
# 14                                       280
# 15                                       280
# 16                                       360
# 17                                       320
# 18                                       200
# 19                                       200
# 20                                       240
# 21                                       160
# 22                                       120
# 23                                        80
# 24                                         0
#
#     Remaining amount returned to bid winner  \
# 0                                         0
# 1                                       400
# 2                                       720
# 3                                       920
# 4                                      1000
# 5                                      1400
# 6                                      1720
# 7                                      2000
# 8                                      2240
# 9                                      2640
# 10                                     2960
# 11                                     3160
# 12                                     3240
# 13                                     3640
# 14                                     3960
# 15                                     4240
# 16                                     4520
# 17                                     4880
# 18                                     5200
# 19                                     5400
# 20                                     5600
# 21                                     5840
# 22                                     6000
# 23                                     6120
# 24                                     6200
#
#     Total amount returned to Bid Winner  Return % for each month's bid winner
# 0                                 37500                                 75.00
# 1                                 39900                                 79.80
# 2                                 43220                                 86.44
# 3                                 46420                                 92.84
# 4                                 38500                                 77.00
# 5                                 40900                                 81.80
# 6                                 42220                                 84.44
# 7                                 43500                                 87.00
# 8                                 39740                                 79.48
# 9                                 42140                                 84.28
# 10                                45460                                 90.92
# 11                                48660                                 97.32
# 12                                40740                                 81.48
# 13                                43140                                 86.28
# 14                                44460                                 88.92
# 15                                44740                                 89.48
# 16                                43020                                 86.04
# 17                                44380                                 88.76
# 18                                47700                                 95.40
# 19                                47900                                 95.80
# 20                                47100                                 94.20
# 21                                49340                                 98.68
# 22                                50500                                101.00
# 23                                51620                                103.24
# 24                                53700                                107.40

# %%
sns.distplot(df["Total amount returned to Bid Winner"], kde=False,bins=10,color='b')

# %%
df[["Total amount returned to Bid Winner","Return % for each month's bid winner"]]
# Out:
#     Total amount returned to Bid Winner  Return % for each month's bid winner
# 0                                 37500                                 75.00
# 1                                 39900                                 79.80
# 2                                 43220                                 86.44
# 3                                 46420                                 92.84
# 4                                 38500                                 77.00
# 5                                 40900                                 81.80
# 6                                 42220                                 84.44
# 7                                 43500                                 87.00
# 8                                 39740                                 79.48
# 9                                 42140                                 84.28
# 10                                45460                                 90.92
# 11                                48660                                 97.32
# 12                                40740                                 81.48
# 13                                43140                                 86.28
# 14                                44460                                 88.92
# 15                                44740                                 89.48
# 16                                43020                                 86.04
# 17                                44380                                 88.76
# 18                                47700                                 95.40
# 19                                47900                                 95.80
# 20                                47100                                 94.20
# 21                                49340                                 98.68
# 22                                50500                                101.00
# 23                                51620                                103.24
# 24                                53700                                107.40

# %%
# Percentage returns for each months bid winner
df["Return % for each month's bid winner"]
# Out:
# 0      75.00
# 1      79.80
# 2      86.44
# 3      92.84
# 4      77.00
# 5      81.80
# 6      84.44
# 7      87.00
# 8      79.48
# 9      84.28
# 10     90.92
# 11     97.32
# 12     81.48
# 13     86.28
# 14     88.92
# 15     89.48
# 16     86.04
# 17     88.76
# 18     95.40
# 19     95.80
# 20     94.20
# 21     98.68
# 22    101.00
# 23    103.24
# 24    107.40
# Name: Return % for each month's bid winner, dtype: float64

# %% [markdown]
# # Task Given :
#
#
#
#
# # 	•	What is the Annualized  Return of the person who bids in the last month ?
# ### 25 months- invetsed 2000per/month = 50,000 -
# ### Returns=  53700rs -i.e  107.40%
# .
#
# .
# .
# .
#
# # 	•	What is the Annualized Return of the person who bids in the first month ?
# ### 25 months- invetsed 2000per/month = 50,000 -
# ### Returns=  37500rs -  i.e 75.00%
#  .
#   .
#   .
#   .
#
#
# # 	•	Write an R/Python script which calculates the annualized return of chit fund participant ?- Show the Return % for each month's bid winner.
#
#
# ####  Month -  , -Total amount returned to Bid Winner each month   -   ,   -  Return % for each month's bid winner
#
# ## 0	-      37500rs	   -  75.00%
# ## 1	-     39900rs	   -  79.80%
# ## 2	-      43220rs  - 	 86.44%
# ## 3	-     	46420rs  -  92.84%
# ## 4	-     	38500rs	  -  77.00%
# ## 5	-     	40900rs	  -  81.80%
# ## 6	-     	42220rs	  -  84.44%
# ## 7	-     	43500rs	  -  87.00%
# ## 8	-     	39740rs - 	 	79.48%
# ## 9	-     	42140rs	 - 	 84.28%
# ## 10	-     	45460rs	 - 	 90.92%
# ## 11	-       	48660rs - 	 	97.32%
# ## 12	-     	40740rs	 - 	 81.48%
# ## 13	-     	43140rs - 		 	86.28%
# ## 14	-     	44460rs - 	88.92%
# ## 15	-     	44740rs - 	89.48%
# ## 16	-     	43020rs - 	 	86.04%
# ## 17	-     	44380rs	 - 	 88.76%
# ## 18	-     	47700rs	 - 	 	 95.40%
# ## 19	-     	47900rs	 - 	  	 95.80%
# ## 20	-     	47100rs	 - 	 94.20%
# ## 21	-     	49340rs	 - 	 	 98.68%
# ## 22	-     	50500rs	 - 	 101.00%
# ## 23	-     	51620rs	 - 	 103.24%
# ## 24	-     	53700rs	 - 	 107.40%
#
# ## index in python starts from Zero i.e 24slno is 25th month
